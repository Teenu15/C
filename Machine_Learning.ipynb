# %% [markdown]
# <a href="https://colab.research.google.com/github/Teenu15/C/blob/main/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Titanic.csv')

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df['Travelalone'] = np.where((df['sibsp'] + df ['parch']) > 0, 0, 1).astype('uint8')

# %%
df1 = df.drop(['pclass', 'name', 'sibsp', 'parch', 'ticket', 'cabin'], axis = 1)

# %%
df1.isna().sum()
# Out:
# survived          0
# sex               0
# age             263
# fare              1
# embarked          2
# boat            823
# body           1188
# home.dest       564
# Travelalone       0
# dtype: int64

# %%
df['age'] = df['age'].fillna(df1['age'].median(skipna=True))

# %%
df1.head()
# Out:
#    survived     sex    age      fare embarked boat   body  \
# 0         1  female  29.00  211.3375        S    2    NaN
# 1         1    male   0.92  151.5500        S   11    NaN
# 2         0  female   2.00  151.5500        S  NaN    NaN
# 3         0    male  30.00  151.5500        S  NaN  135.0
# 4         0  female  25.00  151.5500        S  NaN    NaN
#
#                          home.dest  Travelalone
# 0                     St Louis, MO            1
# 1  Montreal, PQ / Chesterville, ON            0
# 2  Montreal, PQ / Chesterville, ON            0
# 3  Montreal, PQ / Chesterville, ON            0
# 4  Montreal, PQ / Chesterville, ON            0

# %%
df_titanic = pd.get_dummies(df1, columns=['embarked', 'sex'], drop_first=True)

# %%
df_titanic.head()
# Out:
#    survived    age      fare boat   body                        home.dest  \
# 0         1  29.00  211.3375    2    NaN                     St Louis, MO
# 1         1   0.92  151.5500   11    NaN  Montreal, PQ / Chesterville, ON
# 2         0   2.00  151.5500  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3         0  30.00  151.5500  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4         0  25.00  151.5500  NaN    NaN  Montreal, PQ / Chesterville, ON
#
#    Travelalone  embarked_Q  embarked_S  sex_male
# 0            1       False        True     False
# 1            0       False        True      True
# 2            0       False        True     False
# 3            0       False        True      True
# 4            0       False        True     False

# %%
x = df_titanic.drop(['survived'], axis = 1)
y = df_titanic['survived']

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
trans_MM = MinMaxScaler()
trans_SS = StandardScaler()

# %%
df_titanic['boat'] = pd.to_numeric(df_titanic['boat'], errors='coerce').fillna(0)
x = df_titanic.drop(['survived'], axis=1)
df_MM = trans_MM.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e83b21027d73> in <cell line: 0>()
#       1 df_titanic['boat'] = pd.to_numeric(df_titanic['boat'], errors='coerce').fillna(0)
#       2 x = df_titanic.drop(['survived'], axis=1)
# ----> 3 df_MM = trans_MM.fit_transform(x)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...
